# %%
import numpy as np   
import pandas as pd    
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics
import matplotlib.pyplot as plt   
import matplotlib.style
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix
X = StandardScaler()

# %%
df = pd.read_csv("Holiday_Package.csv")

# %%
df
# Out:
#      Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0             1               no   48412   30     8                  1
# 1             2              yes   37207   45     8                  0
# 2             3               no   58022   46     9                  0
# 3             4               no   66503   31    11                  2
# 4             5               no   66734   44    12                  0
# ..          ...              ...     ...  ...   ...                ...
# 867         868               no   40030   24     4                  2
# 868         869              yes   32137   48     8                  0
# 869         870               no   25178   24     6                  2
# 870         871              yes   55958   41    10                  0
# 871         872               no   74659   51    10                  0
#
#      no_older_children foreign
# 0                    1      no
# 1                    1      no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         872 non-null    int64
#  1   Holliday_Package   872 non-null    object
#  2   Salary             872 non-null    int64
#  3   age                872 non-null    int64
#  4   educ               872 non-null    int64
#  5   no_young_children  872 non-null    int64
#  6   no_older_children  872 non-null    int64
#  7   foreign            872 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 54.6+ KB

# %%
df.describe().T
# Out:
#                    count          mean           std     min       25%  \
# Unnamed: 0         872.0    436.500000    251.869014     1.0    218.75
# Salary             872.0  47729.172018  23418.668531  1322.0  35324.00
# age                872.0     39.955275     10.551675    20.0     32.00
# educ               872.0      9.307339      3.036259     1.0      8.00
# no_young_children  872.0      0.311927      0.612870     0.0      0.00
# no_older_children  872.0      0.982798      1.086786     0.0      0.00
#
#                        50%       75%       max
# Unnamed: 0           436.5    654.25     872.0
# Salary             41903.5  53469.50  236961.0
# age                   39.0     48.00      62.0
# educ                   9.0     12.00      21.0
# no_young_children      0.0      0.00       3.0
# no_older_children      1.0      2.00       6.0

# %%
df.describe(include=['object'])
# Out:
#        Holliday_Package foreign
# count               872     872
# unique                2       2
# top                  no      no
# freq                471     656

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Holliday_Package     0
# Salary               0
# age                  0
# educ                 0
# no_young_children    0
# no_older_children    0
# foreign              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
plt.figure(figsize =(10,10))
plt.subplot(6,1,1)
sns.boxplot(x=df['Salary'],palette = 'Blues')

plt.figure(figsize =(10,10))
plt.subplot(6,1,1)
sns.boxplot(x=df['age'],palette = 'Blues')

plt.figure(figsize =(10,10))
plt.subplot(6,1,1)
sns.boxplot(x=df['educ'],palette = 'Blues')

plt.figure(figsize =(10,10))
plt.subplot(6,1,1)
sns.boxplot(x=df['no_young_children'],palette = 'Blues')

plt.figure(figsize =(10,10))
plt.subplot(6,1,1)
sns.boxplot(x=df['no_older_children'],palette = 'Blues')

# %%
df
# Out:
#     Holliday_Package  Salary  age  educ  no_young_children  no_older_children  \
# 0                 no   48412   30     8                  1                  1
# 1                yes   37207   45     8                  0                  1
# 2                 no   58022   46     9                  0                  0
# 3                 no   66503   31    11                  2                  0
# 4                 no   66734   44    12                  0                  2
# ..               ...     ...  ...   ...                ...                ...
# 867               no   40030   24     4                  2                  1
# 868              yes   32137   48     8                  0                  0
# 869               no   25178   24     6                  2                  0
# 870              yes   55958   41    10                  0                  1
# 871               no   74659   51    10                  0                  0
#
#     foreign
# 0        no
# ...

# %%
plt.figure(figsize =(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df )

# %%
df.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C67B87FA08>,
# ...
#       dtype=object)

# %%
print("\t\t     Skewness")
df.skew()
# Out:
# 		     Skewness
# Salary               3.103216
# age                  0.146412
# educ                -0.045501
# no_young_children    1.946515
# no_older_children    0.953951
# dtype: float64

# %%
Desc = pd.DataFrame()
Desc['Variables'] = [ 'Salary', 'age', 'educ',
       'no_young_children','no_older_children']
Desc['IQR'] = [#np.quantile(df['Holliday_Package'],0.75) - np.quantile(df['Holliday_Package'],0.25),
               np.quantile(df['Salary'],0.75) - np.quantile(df['Salary'],0.25),
               np.quantile(df['age'],0.75) - np.quantile(df['age'],0.25),
               np.quantile(df['educ'],0.75) - np.quantile(df['educ'],0.25),
               np.quantile(df['no_young_children'],0.75) - np.quantile(df['no_young_children'],0.25),
               np.quantile(df['no_older_children'],0.75) - np.quantile(df['no_older_children'],0.25),
               #np.quantile(df['foreign'],0.75) - np.quantile(df['foreign'],0.25),
              ]
Desc['Range'] = [str(df['Salary'].min())+'-'+str(df['Salary'].max()),
                 str(df['age'].min())+'-'+str(df['age'].max()),
                 str(df['educ'].min())+'-'+str(df['educ'].max()),
                 str(df['no_young_children'].min())+'-'+str(df['no_young_children'].max()),
                 str(df['no_older_children'].min())+'-'+str(df['no_older_children'].max()),
                 #df['foreign'].min()-df['foreign'].min()
                ]
Desc['Mean'] = [#df['Holliday_Package'].mean(),
                 df['Salary'].mean(),
                 df['age'].mean(),
                 df['educ'].mean(),
                 df['no_young_children'].mean(),
                 df['no_older_children'].mean(),
                 #df['foreign'].mean()
                ]
Desc['Median'] = [#df['Holliday_Package'].median(),
                 df['Salary'].median(),
                 df['age'].median(),
                 df['educ'].median(),
                 df['no_young_children'].median(),
                 df['no_older_children'].median(),
                 #df['foreign'].median()
                ]
Desc['Mode'] =  [#df['Holliday_Package'].mode()[0],
                 df['Salary'].mode()[0],
                 df['age'].mode()[0],
                 df['educ'].mode()[0],
                 df['no_young_children'].mode()[0],
                 df['no_older_children'].mode()[0],
                 #df['foreign'].mode()[0]
                ]
Desc
# Out:
#            Variables      IQR        Range          Mean   Median   Mode
# 0             Salary  18145.5  1322-236961  47729.172018  41903.5  32197
# 1                age     16.0        20-62     39.955275     39.0     44
# 2               educ      4.0         1-21      9.307339      9.0      8
# 3  no_young_children      0.0          0-3      0.311927      0.0      0
# 4  no_older_children      2.0          0-6      0.982798      1.0      0

# %%
from sklearn.preprocessing import LabelEncoder   # import label encoder

labelencoder = LabelEncoder()  

df["Holliday_Package"] = labelencoder.fit_transform(df.Holliday_Package)
df["foreign"] = labelencoder.fit_transform(df.foreign)

# %%
plt.figure(figsize =(10,5))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(5,5))
ax = sns.catplot(x="no_older_children",kind='point',data=df,y='Holliday_Package')

# %% [markdown]
# Number of older children does not seem like a good predictor on deciding whether an employee is likely to take Holiday Package or not as there is approximately equal chance for employess with 4 or less older children to take the package. Employees with number of older children as 5 does not tend to take the package whereas Employees with number of older children as 6 tend to take the package. But there are very few records with number of older children as 5 or 6

# %%
df[(df['no_older_children']==5) | (df['no_older_children']==6)]
# Out:
#      Holliday_Package  Salary  age  educ  no_young_children  \
# 95                  0   63102   48     8                  0
# 186                 0   55269   39     8                  0
# 230                 1   49052   45     8                  0
# 435                 1   28158   40     9                  0
#
#      no_older_children  foreign
# 95                   5        0
# 186                  5        0
# 230                  6        0
# 435                  6        0

# %%
plt.figure(figsize=(5,5))
ax = sns.catplot(x="no_young_children",kind='point',data=df,y='Holliday_Package')

# %% [markdown]
# There is an equal chance for people having no young children to opt or not opt a Holiday Package. But as the number of children increases to 1 and 2, we can see that per cent of people to prefer a Holiday Package is decreasing although there is slight increase in the per cent when it comes to family with 3 young children.

# %%
plt.figure(figsize=(5,5))
ax = sns.catplot(x="foreign",kind='count',data=df,hue='Holliday_Package')

# %% [markdown]
# Most of the foreigners tend to take a Holiday Package wheras most of the non foreigners does not prefer to take a Holiday Package

# %%
sns.lmplot(x='Salary',y='Holliday_Package',data=df,height=5)

# %%
sns.lmplot(x='age',y='Holliday_Package',data=df,height=5)

# %% [markdown]
# Employees with higher Salary does not tend to opt for a Holliday Package. For the given dataset, none of the employees with Salary greater than 140000 has opted for the package

# %%
# Copy all the independent variables into X dataframe
X = df.drop('Holliday_Package', axis=1)

# Copy target variable into the y dataframe. 
y = df[['Holliday_Package']]

# %%
### Data Split: Split the data into train and test (70:30).

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
X_train
# Out:
#      Salary  age  educ  no_young_children  no_older_children  foreign
# 502   34017   57     5                  0                  0        0
# 729   32197   22     6                  1                  0        1
# 604  132984   31    12                  2                  0        0
# 246   72394   50    14                  0                  1        0
# 494   28596   49    15                  0                  0        0
# ..      ...  ...   ...                ...                ...      ...
# 715   40124   54     5                  0                  0        1
# 767   36976   26     5                  0                  1        1
# 72    39663   55     8                  0                  0        0
# 235   98668   55    14                  0                  0        0
# 37    99423   50     8                  0                  1        0
#
# [610 rows x 6 columns]

# %%
X_test
# Out:
#      Salary  age  educ  no_young_children  no_older_children  foreign
# 523   74580   29    13                  1                  0        0
# 731   36564   47     5                  0                  1        1
# 180   40635   24     8                  2                  0        0
# 185  124627   32    13                  2                  1        0
# 435   28158   40     9                  0                  6        0
# ..      ...  ...   ...                ...                ...      ...
# 855  106302   47    13                  0                  0        1
# 76    50291   34    10                  0                  2        0
# 857   56718   33    14                  0                  2        1
# 856   49318   31    16                  2                  0        1
# 132   50003   57     8                  0                  0        0
#
# [262 rows x 6 columns]

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_iter': [20,50,100,150], #5000,2500,3000,2000,1000,1500,500,600
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],#, 'sgd'
    'tol': [0.01,0.1,0.001], 
}

nncl = LogisticRegression(random_state=1,verbose=True)

grid_search = GridSearchCV(estimator = nncl, param_grid = param_grid, cv = 10)

# %%
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
best_grid = grid_search.best_estimator_
best_grid
# Out:
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\optimize.py:212: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   "number of iterations.", ConvergenceWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# C:\Users\user\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
ytest_predict = best_grid.predict(X_test)
model_score = best_grid.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, ytest_predict))
print(metrics.classification_report(y_test, ytest_predict))
model.max_iter

# %%
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
LR_metrics=classification_report(y_test, ytest_predict,output_dict=True)
df_stat=pd.DataFrame(LR_metrics).transpose()
LR_test_precision=round(df_stat.loc["1"][0],2)
LR_test_recall=round(df_stat.loc["1"][1],2)
LR_test_f1=round(df_stat.loc["1"][2],2)
LR_test_acc=round(df_stat.loc["accuracy"]["precision"],2)

# %%
#ytrain_predict = model.predict(X_train)
model_score = best_grid.score(X_train, y_train)
print(model_score)
print(metrics.confusion_matrix(y_train, ytrain_predict))
print(metrics.classification_report(y_train, ytrain_predict))

# %%
LR_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
df_stat=pd.DataFrame(LR_metrics).transpose()
LR_train_precision=round(df_stat.loc["1"][0],2)
LR_train_recall=round(df_stat.loc["1"][1],2)
LR_train_f1=round(df_stat.loc["1"][2],2)
LR_train_acc=round(df_stat.loc["accuracy"]["precision"],2)

# %%
probs = best_grid.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
lr_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % lr_train_auc)
# calculate roc curve
lr_train_fpr, lr_train_tpr, lr_train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(lr_train_fpr, lr_train_tpr)

# %%
probs = best_grid.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
lr_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % lr_test_auc)
# calculate roc curve
lr_test_fpr, lr_test_tpr, lr_test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(lr_test_fpr, lr_test_tpr)

# %%
param_grid = {
    'solver': ['svd'],#, 'sgd'
    'tol': [0.01,0.1,0.001,0.0001], 
}

nncl = LinearDiscriminantAnalysis()

grid_search = GridSearchCV(estimator = nncl, param_grid = param_grid, cv = 10)

# %%
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
best_grid = grid_search.best_estimator_
best_grid

# %%
clf = LinearDiscriminantAnalysis()
LDAmodel=clf.fit(X_train,y_train)
LDAmodel

# %%
ytrain_predict = LDAmodel.predict(X_train)
LDAmodel_score = LDAmodel.score(X_train, y_train)
print(LDAmodel_score)
print(metrics.confusion_matrix(y_train, ytrain_predict))
print(metrics.classification_report(y_train, ytrain_predict))

# %%
LDA_metrics=classification_report(y_train, ytrain_predict,output_dict=True)
df_stat=pd.DataFrame(LDA_metrics).transpose()
LDA_train_precision=round(df_stat.loc["1"][0],2)
LDA_train_recall=round(df_stat.loc["1"][1],2)
LDA_train_f1=round(df_stat.loc["1"][2],2)
LDA_train_acc=round(df_stat.loc["accuracy"]["precision"],2)

# %%
ytest_predict = LDAmodel.predict(X_test)
LDAmodel_score = LDAmodel.score(X_test, y_test)
print(LDAmodel_score)
print(metrics.confusion_matrix(y_test, ytest_predict))
print(metrics.classification_report(y_test, ytest_predict))

# %%
LDA_metrics=classification_report(y_test, ytest_predict,output_dict=True)
df_stat=pd.DataFrame(LDA_metrics).transpose()
LDA_test_precision=round(df_stat.loc["1"][0],2)
LDA_test_recall=round(df_stat.loc["1"][1],2)
LDA_test_f1=round(df_stat.loc["1"][2],2)
LDA_test_acc=round(df_stat.loc["accuracy"]["precision"],2)

# %%
probs = LDAmodel.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
lda_train_auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % lda_train_auc)
# calculate roc curve
lda_train_fpr, lda_train_tpr, lda_train_thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(lda_train_fpr, lda_train_tpr)

# %%
probs = LDAmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
lda_test_auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % lda_test_auc)
# calculate roc curve
lda_test_fpr, lda_test_tpr, lda_test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(lda_test_fpr, lda_test_tpr)

# %%
LDAmodel.coef_

# %%
LDAmodel.intercept_

# %%
best_grid.coef_

# %%
best_grid.intercept_

# %%
X_train

# %%
X_test

# %%
index=['Accuracy', 'AUC', 'Recall','Precision','F1 Score']
data = pd.DataFrame({'Logistic Reg Train':[LR_train_acc,lr_train_auc,LR_train_recall,LR_train_precision,LR_train_f1],
        'Logistic Reg Test':[LR_test_acc,lr_test_auc,LR_test_recall,LR_test_precision,LR_test_f1],
       'LDA Train':[LDA_train_acc,lda_train_auc,LDA_train_recall,LDA_train_precision,LDA_train_f1],
        'LDA Test':[LDA_test_acc,lda_test_auc,LDA_test_recall,LDA_test_precision,LDA_test_f1]},index=index)
round(data,2)
